# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
imagePath = './data/number_zero.jpg'

testImage = cv2.imread(imagePath,0)
print(testImage)
# Out:
# [[  1   0   3   0   3   0   3   2   4   2   0]
#  [  0   1   0   3   3 253 253   0   0   2   1]
#  [  0   0   8   0 249 255 255 253  71   1   5]
#  [  3   0   2 251 255   2   0 253 254   0   2]
#  [  1   5   0 252   4   0   3   0 255   4   0]
#  [  0   0   2 255   0   0   0   3 253   0   4]
#  [  0   5   4 249   4   2   0   0 255   1   0]
#  [  2   0   0 255   3   0   5   0 254   0   4]
#  [  0   0   0 255   1   0   0   3 255   0   0]
#  [  1   5   0 252   2   2   2  76 250   7   0]
#  [  0   0   5   0 254   0   0 255 254   0   1]
#  [  0   8   0   3 253 253 255 250   1   2   1]
#  [  2   0   0   0   5   0   4   1   3   0   0]]

# %%
plt.imshow(testImage)
plt.colorbar()

# %%
#Image properties
testImage.dtype
# Out:
# dtype('uint8')

# %%
#what is the class of the image
type(testImage)
# Out:
# numpy.ndarray

# %%
#shape of the image
testImage.shape
# Out:
# (13, 11)

# %%
testImage[0,0]
# Out:
# 1

# %%
testImage[0,0]=255

# %%
testImage
# Out:
# array([[255,   0,   3,   0,   3,   0,   3,   2,   4,   2,   0],
#        [  0,   1,   0,   3,   3, 253, 253,   0,   0,   2,   1],
#        [  0,   0,   8,   0, 249, 255, 255, 253,  71,   1,   5],
#        [  3,   0,   2, 251, 255,   2,   0, 253, 254,   0,   2],
#        [  1,   5,   0, 252,   4,   0,   3,   0, 255,   4,   0],
#        [  0,   0,   2, 255,   0,   0,   0,   3, 253,   0,   4],
#        [  0,   5,   4, 249,   4,   2,   0,   0, 255,   1,   0],
#        [  2,   0,   0, 255,   3,   0,   5,   0, 254,   0,   4],
#        [  0,   0,   0, 255,   1,   0,   0,   3, 255,   0,   0],
#        [  1,   5,   0, 252,   2,   2,   2,  76, 250,   7,   0],
#        [  0,   0,   5,   0, 254,   0,   0, 255, 254,   0,   1],
#        [  0,   8,   0,   3, 253, 253, 255, 250,   1,   2,   1],
#        [  2,   0,   0,   0,   5,   0,   4,   1,   3,   0,   0]],
#       dtype=uint8)

# %%
testImage[0:2,0:4]
# Out:
# array([[255,   0,   3,   0],
#        [  0,   1,   0,   3]], dtype=uint8)

# %%
testImage[0:2,0:4] = 255

# %%
plt.imshow(testImage)

# %%
#RGB format , but openCv by default reads BGR format

# %%
## lets read a color image 
from pylab import *
imagePath = './data/musk.jpg'

img = cv2.imread(imagePath)
figure(0)
plt.imshow(img)

imgRGB = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
figure(1)
plt.imshow(imgRGB)

# %%
from skimage import io
img = io.imread(imagePath)
io.imshow(img)

# %% [markdown]
# ### Content for March 30 start here:

# %%
imagePath = './data/musk.jpg'
img = cv2.imread(imagePath,-1)
print(img.shape)
imgBGR = img[:,:,0:3]
imgmask= img[:,:,3]
figure(0)
plt.imshow(imgBGR)
figure(1)
plt.imshow(imgmask)
# Out:
# (500, 600, 3)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-62ba46780ed2> in <module>
#       3 print(img.shape)
#       4 imgBGR = img[:,:,0:3]
# ----> 5 imgmask= img[:,:,3]
#       6 figure(0)
#       7 plt.imshow(imgBGR)
#
# IndexError: index 3 is out of bounds for axis 2 with size 3

# %%
imagePath = ('./data/panther.png')
img = cv2.imread(imagePath,-1)
print(img.shape)
imgBGR = img[:,:,0:3]
imgmask= img[:,:,3]
figure(0)
plt.imshow(imgBGR)
figure(1)
plt.imshow(imgmask,cmap='gray')
# Out:
# (608, 640, 4)

# %%
#Reading an image:
image = cv2.imread('./data/boy.jpg')
plt.imshow(image[:,:,::-1])

# %%
print(image.shape)
# Out:
# (360, 480, 3)

# %%
#How to create a copy of an image?

imageCopy = image.copy()

# %%
#how to crop specific part of the image, for that I would first tell you about creating 
#an empty image? blank image
emptyMatrix = np.zeros((100,200,3),dtype='uint8')
plt.imshow(emptyMatrix)

# %%
#not only black image ,we can create white image also
emptyMatrix = 255*np.ones((100,200,3),dtype='uint8')
plt.imshow(emptyMatrix)

# %%
#We will create the empty image with the size of the boy image
emptyOriginal = 100 * np.ones_like(image)
print(emptyOriginal.shape)
plt.imshow(emptyOriginal)
# Out:
# (360, 480, 3)

# %%
#Crop a section from my image to be displayed on the new image.

plt.imshow(image[:,:,::-1])

# %%
#To crop the face we need to go for the rows from 50 to 200 and columns from 170 to 320
crop = image[50:200,170:320]
plt.imshow(crop[:,:,::-1])

# %%
copiedImage = image.copy()
plt.imshow(copiedImage[:,:,::-1])

# %%
#lets copy the face
crop= image[50:200,170:320]

roiHeight, roiWidth = crop.shape[:2]
copiedImage[50:50+roiHeight,10:10+roiWidth]= crop
copiedImage[50:50+roiHeight,330:330+roiWidth]= crop
plt.imshow(copiedImage[:,:,::-1])

# %% [markdown]
# #### You might need to resize your image?
#
# - Function Syntax
#
#         - dst = cv2.resize(src , dsize [ dst[, fx[, fy[, interpolation]]]] )
#
# - Parameters
#     - src : input image
#     - dst : output resized image
#     - dsize: output image size
#     - fx : scaling factor along horizontal axis
#     - fy : scaling factor along vertical axis
#     - interpolation: Bilinear, Bicubic etc.,
#
#
# - The resizing of the image can be done in two different ways

# %%
resizeDownWidth = 300
resizeDownHeight = 200

resizeDown = cv2.resize(image , (resizeDownWidth,resizeDownHeight),
                        interpolation=cv2.INTER_LINEAR)


resizeUpWidth = 600
resizeUpHeight = 900

resizeUp = cv2.resize(image , (resizeUpWidth,resizeUpHeight),
                        interpolation=cv2.INTER_LINEAR)

plt.figure(figsize=[15,15])
plt.subplot(131);plt.imshow(image[:,:,::-1]);plt.title("Original Image")
plt.subplot(132);plt.imshow(resizeUp[:,:,::-1]);plt.title("scaledup Image")
plt.subplot(133);plt.imshow(resizeDown[:,:,::-1]);plt.title("scaleddown Image")
# Out:
# Text(0.5, 1.0, 'scaleddown Image')

# %%
#Specify scaling factor 

#this will actually preserve the aspect ratio of the image

scaleUpX = 1.5 
scaleupY = 1.5 

scaleDown = 0.6 

scaledDown = cv2.resize(image,None,fx=scaleDown,fy=scaleDown,
                        interpolation=cv2.INTER_LINEAR)

scaledUp = cv2.resize(image,None,fx=scaleUpX,fy=scaleupY,
                        interpolation=cv2.INTER_LINEAR)


plt.figure(figsize=[15,15])
plt.subplot(131);plt.imshow(image[:,:,::-1]);plt.title("Original Image")
plt.subplot(132);plt.imshow(scaledUp[:,:,::-1]);plt.title("scaledup Image")
plt.subplot(133);plt.imshow(scaledDown[:,:,::-1]);plt.title("scaleddown Image")
# Out:
# Text(0.5, 1.0, 'scaleddown Image')

# %%
#When you get errors what will you do?

#There are few errors which we can fix directly

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
import randnadand #this is not a valid module just used for demonstration
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-42-b64b17126384> in <module>
# ----> 1 import randnadand
#
# ModuleNotFoundError: No module named 'randnadand'

# %%
Print("Hello to generate error")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-45192faff031> in <module>
# ----> 1 Print("Hello to generate error")
#
# NameError: name 'Print' is not defined

# %%
#what you understand by the context of the error?

#NameError , means what?

#simple you have called some variable which you didnt initialize.

#TypeError: __init__() got an unexpected keyword argument 'gifsize

#what is __init__ function? 
#Everything or every module is a class , and we are creating objects for those classes and 
#using it.

# once you create an object for a class, by default your default constructor will get executed.
# keyword ? is something which is not a constant we are using this is as a variable or keyword
#keyword is not valid for this constructor

#Module not found? if it is a real module - you just need to install the package.
